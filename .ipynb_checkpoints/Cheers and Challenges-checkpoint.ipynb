# %% [markdown]
# # Welcome back!
#
# ![image](https://image.shutterstock.com/image-photo/two-red-coffee-mugs-smiling-260nw-1128835331.jpg)
#
# Today we are going to write a script to assign cheers and challenges dates to interns:
#
# Our goal is to assign a name to each Thursday date between now and the end of the year. Something like this:
#
# ![image](https://raw.githubusercontent.com/madesai22/ocean-ml/master/images/final_product.jpeg)
#
# To do this, we are going to use the datetime module. The datetime module is used to deal with real dates and times in python. First, we need to import the **date** object from the datetime module:

# %%
from datetime import date

# %% [markdown]
# With this, we can create variables that are date objects:

# %%
meeras_birthday = date(1996,5,22)
today = date.today()

print(today)
# add your birthday here:
# Out:
# 2019-10-21

# %% [markdown]
# We're also going to import the **timedelta** object from the datetime module:

# %%
from datetime import timedelta

# %% [markdown]
# The timedelta object is for adding or subtracting times from one another. For example, when you subtract two dates, the result is a timedelta object:

# %%
# timedelta Example 1: 
meeras_age = today - meeras_birthday 
print(type(meeras_age))
# write code to calcualte and print your age and the type of this variable
# Here :
# Out:
# <type 'datetime.timedelta'>

# %% [markdown]
# You can use timedeltas to calculate time in the future or the past:

# %%
# timedelta Example 2:
one_week = timedelta(days = 7)
next_week = today + one_week
print(next_week)
# Out:
# 2019-10-28

# %%
# Write code to calculate the date in two weeks: 


# write code to calculate the date two weeks ago:

# %% [markdown]
# One more thing before we can start writing our script.
# Normally when we want to loop through a list, we get to the end of the list and stop:

# %%
example_list = ['this','is','an','example','list','of','strings']

# write code to iterate through this list and print each item:

# %% [markdown]
# For our purposes, we need to continue to loop through a list. For this we use **cycle** from the itertools module. Let's see what this code does:

# %%
from itertools import cycle 
example_cycle = cycle(example_list)
for item in example_cycle:
    print item

# write code to print the items in example_cycle:
# Out:
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# ...
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list
# of
# strings
# this
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-dc1f76641d0a> in <module>()
#       2 example_cycle = cycle(example_list)
#       3 for item in example_cycle:
# ----> 4     print item
#       5
#       6 # write code to print the items in example_cycle:
#
# /Users/helenfellow/anaconda2/lib/python2.7/site-packages/ipykernel/iostream.pyc in write(self, string)
#     398             is_child = (not self._is_master_process())
#     399             # only touch the buffer in the IO thread to avoid races
# --> 400             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     401             if is_child:
#     402                 # newlines imply flush in subprocesses
#
# /Users/helenfellow/anaconda2/lib/python2.7/site-packages/ipykernel/iostream.pyc in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# /Users/helenfellow/anaconda2/lib/python2.7/site-packages/zmq/sugar/socket.pyc in send(self, data, flags, copy, track, routing_id, group)
#     393                                  copy_threshold=self.copy_threshold)
#     394             data.group = group
# --> 395         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     396
#     397     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /Users/helenfellow/anaconda2/lib/python2.7/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#      10     """
#      11     cdef int errno = zmq_errno()
# ---> 12     PyErr_CheckSignals()
#      13     if rc == -1: # if rc < -1, it's a bug in libzmq. Should we warn?
#      14         if errno == EINTR:
#
# KeyboardInterrupt:

# %% [markdown]
# Uhoh! We can stop an ongoing loop with a **break** statement. We can worry about this when we write our script. Let's start thinking about the variables we need to make our script. One thing we might need is a list of dates we don't need to assign someone to (dates we don't meet or when interns have a workshop). We can store these in a set, which is kind of like a list with some special properites. You denote a set using these brackets { } as shown:

# %%
no_session = { date(2019,11,5), date(2019,11,7), date(2019,11,28), date(2019,12,26),
              date(2020,1,2), date(2020,1,9), date(2020,1,30), date(2020,2,27),
              date(2020,2,20), date(2020,4,2), date(2020,4,9), date(2020,4,16),
              date(2020,6,4)
             }

# %% [markdown]
# Another thing we might need is the start and end dates. We can make the start date today.  The end date is June 6th, 2020.

# %%
# Write code to assign start and end dates to variable here

# %% [markdown]
# What else do we need? How can we use these elements to make a script that does what we want?

# %%
if today not in no_session:
    print(today)
    
i = 0 
while i<12:
    print(next(example_cycle))
    i+= 1
# Out:
# 2019-10-24
# this
# is
# an
# example
# list
# of
# strings
# this
# is
# an
# example
# list

# %%
# Use this space to map out your code. What variables do you need? 

# start, end, list of intern names, list of dates with no sessions, 
# make a loop that prints all the cheers and challenges dates

# step 0: make a loop that prints ALL the thursdays between now and the end of internships

today = date.today()
tomorrow = date(2019,10,25)




if(today<tomorrow):
    print('true')

    
i = 0 
while i <= 9:
    print(3*i)
    i += 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-dc55ce79fda3> in <module>()
#      10
#      11
# ---> 12 if today in no_session:
#      13     print today
#      14
#
# NameError: name 'no_session' is not defined

# %% [markdown]
# Bonus if we have time: How can you write this to a file instead of printing to the screen?

# %%
# write that here if you have time :-)
